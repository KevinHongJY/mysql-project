# %%
from MySqlHelper import MySqlHelper
from datetime import datetime
import requests
from bs4 import BeautifulSoup
import logging
from apscheduler.schedulers.blocking import BlockingScheduler
# 日志配置
logging.basicConfig(
    filename='crawler.log',
    level=logging.INFO,
    format='%(asctime)s %(levelname)s: %(message)s'
)

def init_db(helper: MySqlHelper):
    """创建热搜表"""
    sql = """
    CREATE TABLE IF NOT EXISTS hot_search (
    id INT AUTO_INCREMENT PRIMARY KEY,
    ranking INT NOT NULL,
    title VARCHAR(100) NOT NULL,
    url VARCHAR(200) NOT NULL,
    ts DATETIME NOT NULL
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4;
    """
    helper.execute(sql)

def fetch_hot_search():
    """爬取百度热搜 Top10"""
    url = 'https://top.baidu.com/board?tab=realtime'
    resp = requests.get(url, timeout=10)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, 'lxml')
    items = soup.select('.c-single-text-ellipsis')[:10]

    data = []
    for rank, tag in enumerate(items, start=1):
        title = tag.get_text(strip=True)
        link = tag.parent.get('href')
        # 如果是相对路径，需要补全
        if link and link.startswith('/'):
            link = 'https://top.baidu.com' + link
        ts = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        data.append((rank, title, link, ts))
    return data

def job():
    """一次完整抓取并存库流程"""
    helper = MySqlHelper(
        host='localhost',
        user='root',
        password='@Kevin021117',
        database='school'
    )
    try:
        helper.connect()
        init_db(helper)
        records = fetch_hot_search()
        for rec in records:
            helper.execute(
                "INSERT INTO hot_search(ranking, title, url, ts) VALUES (%s, %s, %s, %s)",
                rec
            )
        logging.info(f"成功插入 {len(records)} 条热搜数据")
    except Exception as e:
        logging.error(f"爬虫任务出错：{e}")
    finally:
        helper.close()



def get_all_hot_search():
    """从数据库里拿出所有热搜，按时间和排名排序"""
    helper = MySqlHelper(
        host='localhost',
        user='root',
        password='@Kevin021117',
        database='school'
    )
    helper.connect()
    sql = """
    SELECT ranking, title, url, ts
    FROM hot_search
    ORDER BY ts DESC, ranking ASC;
    """
    rows = helper.query(sql)
    helper.close()
    return rows

def print_data(rows):
    if not rows:
        print("no data found.")
        return
    print(f"\nFetched {len(rows)} records:")
    print("-" * 80)
    print(f"{'Time':<20}{'Rank':<6}{'Title':<40}")
    print("-" * 80)
    for r in rows:
        ts = r['ts'].strftime('%Y-%m-%d %H:%M:%S') if isinstance(r['ts'], datetime) else r['ts']
        print(f"{ts:<20}{r['ranking']:<6}{r['title']:<40}")
        if r.get('url'):
            print(f" URL: {r['url']}")
    print("-" * 80)

if __name__ == '__main__':
    # 1) 先跑一遍爬虫并存库
    job()

    # 2) 再从库里读出来并打印
    data = get_all_hot_search()
    print_data(data)
# Out:
# Fetched 70 records:
# --------------------------------------------------------------------------------
# Time                Rank  Title
# --------------------------------------------------------------------------------
# 2025-06-11 23:01:41 1     总书记的“家园”之喻
#  URL: https://www.baidu.com/s?wd=%E6%80%BB%E4%B9%A6%E8%AE%B0%E7%9A%84%E2%80%9C%E5%AE%B6%E5%9B%AD%E2%80%9D%E4%B9%8B%E5%96%BB&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:41 2     洛杉矶已面目全非
#  URL: https://www.baidu.com/s?wd=%E6%B4%9B%E6%9D%89%E7%9F%B6%E5%B7%B2%E9%9D%A2%E7%9B%AE%E5%85%A8%E9%9D%9E&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:41 3     高考结束挑行李回家的女生发声
#  URL: https://www.baidu.com/s?wd=%E9%AB%98%E8%80%83%E7%BB%93%E6%9D%9F%E6%8C%91%E8%A1%8C%E6%9D%8E%E5%9B%9E%E5%AE%B6%E7%9A%84%E5%A5%B3%E7%94%9F%E5%8F%91%E5%A3%B0&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:41 4     听听青年的网络文明“关键词”
#  URL: https://www.baidu.com/s?wd=%E5%90%AC%E5%90%AC%E9%9D%92%E5%B9%B4%E7%9A%84%E7%BD%91%E7%BB%9C%E6%96%87%E6%98%8E%E2%80%9C%E5%85%B3%E9%94%AE%E8%AF%8D%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:41 5     阿里离职员工发万字长文 马云回应
#  URL: https://www.baidu.com/s?wd=%E9%98%BF%E9%87%8C%E7%A6%BB%E8%81%8C%E5%91%98%E5%B7%A5%E5%8F%91%E4%B8%87%E5%AD%97%E9%95%BF%E6%96%87+%E9%A9%AC%E4%BA%91%E5%9B%9E%E5%BA%94&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:41 6     扎克伯格1000亿天价买“半个”天才
#  URL: https://www.baidu.com/s?wd=%E6%89%8E%E5%85%8B%E4%BC%AF%E6%A0%BC1000%E4%BA%BF%E5%A4%A9%E4%BB%B7%E4%B9%B0%E2%80%9C%E5%8D%8A%E4%B8%AA%E2%80%9D%E5%A4%A9%E6%89%8D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:41 7     网警：当心你的隐私被“共享”
#  URL: https://www.baidu.com/s?wd=%E7%BD%91%E8%AD%A6%EF%BC%9A%E5%BD%93%E5%BF%83%E4%BD%A0%E7%9A%84%E9%9A%90%E7%A7%81%E8%A2%AB%E2%80%9C%E5%85%B1%E4%BA%AB%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:41 8     迪丽热巴因一句台词一夜涨粉200万
#  URL: https://www.baidu.com/s?wd=%E8%BF%AA%E4%B8%BD%E7%83%AD%E5%B7%B4%E5%9B%A0%E4%B8%80%E5%8F%A5%E5%8F%B0%E8%AF%8D%E4%B8%80%E5%A4%9C%E6%B6%A8%E7%B2%89200%E4%B8%87&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:41 9     “赌王”孙女街头摆摊当小贩
#  URL: https://www.baidu.com/s?wd=%E2%80%9C%E8%B5%8C%E7%8E%8B%E2%80%9D%E5%AD%99%E5%A5%B3%E8%A1%97%E5%A4%B4%E6%91%86%E6%91%8A%E5%BD%93%E5%B0%8F%E8%B4%A9&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:41 10    种粮大户的“丰收密码”
#  URL: https://www.baidu.com/s?wd=%E7%A7%8D%E7%B2%AE%E5%A4%A7%E6%88%B7%E7%9A%84%E2%80%9C%E4%B8%B0%E6%94%B6%E5%AF%86%E7%A0%81%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 1     总书记的“家园”之喻
#  URL: https://www.baidu.com/s?wd=%E6%80%BB%E4%B9%A6%E8%AE%B0%E7%9A%84%E2%80%9C%E5%AE%B6%E5%9B%AD%E2%80%9D%E4%B9%8B%E5%96%BB&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 1     总书记的“家园”之喻
#  URL: https://www.baidu.com/s?wd=%E6%80%BB%E4%B9%A6%E8%AE%B0%E7%9A%84%E2%80%9C%E5%AE%B6%E5%9B%AD%E2%80%9D%E4%B9%8B%E5%96%BB&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 2     洛杉矶已面目全非
#  URL: https://www.baidu.com/s?wd=%E6%B4%9B%E6%9D%89%E7%9F%B6%E5%B7%B2%E9%9D%A2%E7%9B%AE%E5%85%A8%E9%9D%9E&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 2     洛杉矶已面目全非
#  URL: https://www.baidu.com/s?wd=%E6%B4%9B%E6%9D%89%E7%9F%B6%E5%B7%B2%E9%9D%A2%E7%9B%AE%E5%85%A8%E9%9D%9E&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 3     高考结束挑行李回家的女生发声
#  URL: https://www.baidu.com/s?wd=%E9%AB%98%E8%80%83%E7%BB%93%E6%9D%9F%E6%8C%91%E8%A1%8C%E6%9D%8E%E5%9B%9E%E5%AE%B6%E7%9A%84%E5%A5%B3%E7%94%9F%E5%8F%91%E5%A3%B0&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 3     高考结束挑行李回家的女生发声
#  URL: https://www.baidu.com/s?wd=%E9%AB%98%E8%80%83%E7%BB%93%E6%9D%9F%E6%8C%91%E8%A1%8C%E6%9D%8E%E5%9B%9E%E5%AE%B6%E7%9A%84%E5%A5%B3%E7%94%9F%E5%8F%91%E5%A3%B0&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 4     听听青年的网络文明“关键词”
#  URL: https://www.baidu.com/s?wd=%E5%90%AC%E5%90%AC%E9%9D%92%E5%B9%B4%E7%9A%84%E7%BD%91%E7%BB%9C%E6%96%87%E6%98%8E%E2%80%9C%E5%85%B3%E9%94%AE%E8%AF%8D%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 4     听听青年的网络文明“关键词”
#  URL: https://www.baidu.com/s?wd=%E5%90%AC%E5%90%AC%E9%9D%92%E5%B9%B4%E7%9A%84%E7%BD%91%E7%BB%9C%E6%96%87%E6%98%8E%E2%80%9C%E5%85%B3%E9%94%AE%E8%AF%8D%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 5     阿里离职员工发万字长文 马云回应
#  URL: https://www.baidu.com/s?wd=%E9%98%BF%E9%87%8C%E7%A6%BB%E8%81%8C%E5%91%98%E5%B7%A5%E5%8F%91%E4%B8%87%E5%AD%97%E9%95%BF%E6%96%87+%E9%A9%AC%E4%BA%91%E5%9B%9E%E5%BA%94&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 5     阿里离职员工发万字长文 马云回应
#  URL: https://www.baidu.com/s?wd=%E9%98%BF%E9%87%8C%E7%A6%BB%E8%81%8C%E5%91%98%E5%B7%A5%E5%8F%91%E4%B8%87%E5%AD%97%E9%95%BF%E6%96%87+%E9%A9%AC%E4%BA%91%E5%9B%9E%E5%BA%94&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 6     扎克伯格1000亿天价买“半个”天才
#  URL: https://www.baidu.com/s?wd=%E6%89%8E%E5%85%8B%E4%BC%AF%E6%A0%BC1000%E4%BA%BF%E5%A4%A9%E4%BB%B7%E4%B9%B0%E2%80%9C%E5%8D%8A%E4%B8%AA%E2%80%9D%E5%A4%A9%E6%89%8D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 6     扎克伯格1000亿天价买“半个”天才
#  URL: https://www.baidu.com/s?wd=%E6%89%8E%E5%85%8B%E4%BC%AF%E6%A0%BC1000%E4%BA%BF%E5%A4%A9%E4%BB%B7%E4%B9%B0%E2%80%9C%E5%8D%8A%E4%B8%AA%E2%80%9D%E5%A4%A9%E6%89%8D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 7     网警：当心你的隐私被“共享”
#  URL: https://www.baidu.com/s?wd=%E7%BD%91%E8%AD%A6%EF%BC%9A%E5%BD%93%E5%BF%83%E4%BD%A0%E7%9A%84%E9%9A%90%E7%A7%81%E8%A2%AB%E2%80%9C%E5%85%B1%E4%BA%AB%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 7     网警：当心你的隐私被“共享”
#  URL: https://www.baidu.com/s?wd=%E7%BD%91%E8%AD%A6%EF%BC%9A%E5%BD%93%E5%BF%83%E4%BD%A0%E7%9A%84%E9%9A%90%E7%A7%81%E8%A2%AB%E2%80%9C%E5%85%B1%E4%BA%AB%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 8     迪丽热巴因一句台词一夜涨粉200万
#  URL: https://www.baidu.com/s?wd=%E8%BF%AA%E4%B8%BD%E7%83%AD%E5%B7%B4%E5%9B%A0%E4%B8%80%E5%8F%A5%E5%8F%B0%E8%AF%8D%E4%B8%80%E5%A4%9C%E6%B6%A8%E7%B2%89200%E4%B8%87&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 8     迪丽热巴因一句台词一夜涨粉200万
#  URL: https://www.baidu.com/s?wd=%E8%BF%AA%E4%B8%BD%E7%83%AD%E5%B7%B4%E5%9B%A0%E4%B8%80%E5%8F%A5%E5%8F%B0%E8%AF%8D%E4%B8%80%E5%A4%9C%E6%B6%A8%E7%B2%89200%E4%B8%87&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 9     “赌王”孙女街头摆摊当小贩
#  URL: https://www.baidu.com/s?wd=%E2%80%9C%E8%B5%8C%E7%8E%8B%E2%80%9D%E5%AD%99%E5%A5%B3%E8%A1%97%E5%A4%B4%E6%91%86%E6%91%8A%E5%BD%93%E5%B0%8F%E8%B4%A9&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 9     “赌王”孙女街头摆摊当小贩
#  URL: https://www.baidu.com/s?wd=%E2%80%9C%E8%B5%8C%E7%8E%8B%E2%80%9D%E5%AD%99%E5%A5%B3%E8%A1%97%E5%A4%B4%E6%91%86%E6%91%8A%E5%BD%93%E5%B0%8F%E8%B4%A9&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 10    种粮大户的“丰收密码”
#  URL: https://www.baidu.com/s?wd=%E7%A7%8D%E7%B2%AE%E5%A4%A7%E6%88%B7%E7%9A%84%E2%80%9C%E4%B8%B0%E6%94%B6%E5%AF%86%E7%A0%81%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 23:01:28 10    种粮大户的“丰收密码”
#  URL: https://www.baidu.com/s?wd=%E7%A7%8D%E7%B2%AE%E5%A4%A7%E6%88%B7%E7%9A%84%E2%80%9C%E4%B8%B0%E6%94%B6%E5%AF%86%E7%A0%81%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:59:15 1     总书记的“家园”之喻
#  URL: https://www.baidu.com/s?wd=%E6%80%BB%E4%B9%A6%E8%AE%B0%E7%9A%84%E2%80%9C%E5%AE%B6%E5%9B%AD%E2%80%9D%E4%B9%8B%E5%96%BB&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:59:15 2     洛杉矶已面目全非
#  URL: https://www.baidu.com/s?wd=%E6%B4%9B%E6%9D%89%E7%9F%B6%E5%B7%B2%E9%9D%A2%E7%9B%AE%E5%85%A8%E9%9D%9E&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:59:15 3     高考结束挑行李回家的女生发声
#  URL: https://www.baidu.com/s?wd=%E9%AB%98%E8%80%83%E7%BB%93%E6%9D%9F%E6%8C%91%E8%A1%8C%E6%9D%8E%E5%9B%9E%E5%AE%B6%E7%9A%84%E5%A5%B3%E7%94%9F%E5%8F%91%E5%A3%B0&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:59:15 4     听听青年的网络文明“关键词”
#  URL: https://www.baidu.com/s?wd=%E5%90%AC%E5%90%AC%E9%9D%92%E5%B9%B4%E7%9A%84%E7%BD%91%E7%BB%9C%E6%96%87%E6%98%8E%E2%80%9C%E5%85%B3%E9%94%AE%E8%AF%8D%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:59:15 5     阿里离职员工发万字长文 马云回应
#  URL: https://www.baidu.com/s?wd=%E9%98%BF%E9%87%8C%E7%A6%BB%E8%81%8C%E5%91%98%E5%B7%A5%E5%8F%91%E4%B8%87%E5%AD%97%E9%95%BF%E6%96%87+%E9%A9%AC%E4%BA%91%E5%9B%9E%E5%BA%94&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:59:15 6     扎克伯格1000亿天价买“半个”天才
#  URL: https://www.baidu.com/s?wd=%E6%89%8E%E5%85%8B%E4%BC%AF%E6%A0%BC1000%E4%BA%BF%E5%A4%A9%E4%BB%B7%E4%B9%B0%E2%80%9C%E5%8D%8A%E4%B8%AA%E2%80%9D%E5%A4%A9%E6%89%8D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:59:15 7     网警：当心你的隐私被“共享”
#  URL: https://www.baidu.com/s?wd=%E7%BD%91%E8%AD%A6%EF%BC%9A%E5%BD%93%E5%BF%83%E4%BD%A0%E7%9A%84%E9%9A%90%E7%A7%81%E8%A2%AB%E2%80%9C%E5%85%B1%E4%BA%AB%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:59:15 8     迪丽热巴因一句台词一夜涨粉200万
#  URL: https://www.baidu.com/s?wd=%E8%BF%AA%E4%B8%BD%E7%83%AD%E5%B7%B4%E5%9B%A0%E4%B8%80%E5%8F%A5%E5%8F%B0%E8%AF%8D%E4%B8%80%E5%A4%9C%E6%B6%A8%E7%B2%89200%E4%B8%87&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:59:15 9     “赌王”孙女街头摆摊当小贩
#  URL: https://www.baidu.com/s?wd=%E2%80%9C%E8%B5%8C%E7%8E%8B%E2%80%9D%E5%AD%99%E5%A5%B3%E8%A1%97%E5%A4%B4%E6%91%86%E6%91%8A%E5%BD%93%E5%B0%8F%E8%B4%A9&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:59:15 10    种粮大户的“丰收密码”
#  URL: https://www.baidu.com/s?wd=%E7%A7%8D%E7%B2%AE%E5%A4%A7%E6%88%B7%E7%9A%84%E2%80%9C%E4%B8%B0%E6%94%B6%E5%AF%86%E7%A0%81%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:57:20 1     总书记的“家园”之喻
#  URL: https://www.baidu.com/s?wd=%E6%80%BB%E4%B9%A6%E8%AE%B0%E7%9A%84%E2%80%9C%E5%AE%B6%E5%9B%AD%E2%80%9D%E4%B9%8B%E5%96%BB&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:57:20 2     洛杉矶已面目全非
#  URL: https://www.baidu.com/s?wd=%E6%B4%9B%E6%9D%89%E7%9F%B6%E5%B7%B2%E9%9D%A2%E7%9B%AE%E5%85%A8%E9%9D%9E&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:57:20 3     高考结束挑行李回家的女生发声
#  URL: https://www.baidu.com/s?wd=%E9%AB%98%E8%80%83%E7%BB%93%E6%9D%9F%E6%8C%91%E8%A1%8C%E6%9D%8E%E5%9B%9E%E5%AE%B6%E7%9A%84%E5%A5%B3%E7%94%9F%E5%8F%91%E5%A3%B0&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:57:20 4     听听青年的网络文明“关键词”
#  URL: https://www.baidu.com/s?wd=%E5%90%AC%E5%90%AC%E9%9D%92%E5%B9%B4%E7%9A%84%E7%BD%91%E7%BB%9C%E6%96%87%E6%98%8E%E2%80%9C%E5%85%B3%E9%94%AE%E8%AF%8D%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:57:20 5     阿里离职员工发万字长文 马云回应
#  URL: https://www.baidu.com/s?wd=%E9%98%BF%E9%87%8C%E7%A6%BB%E8%81%8C%E5%91%98%E5%B7%A5%E5%8F%91%E4%B8%87%E5%AD%97%E9%95%BF%E6%96%87+%E9%A9%AC%E4%BA%91%E5%9B%9E%E5%BA%94&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:57:20 6     扎克伯格1000亿天价买“半个”天才
#  URL: https://www.baidu.com/s?wd=%E6%89%8E%E5%85%8B%E4%BC%AF%E6%A0%BC1000%E4%BA%BF%E5%A4%A9%E4%BB%B7%E4%B9%B0%E2%80%9C%E5%8D%8A%E4%B8%AA%E2%80%9D%E5%A4%A9%E6%89%8D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:57:20 7     网警：当心你的隐私被“共享”
#  URL: https://www.baidu.com/s?wd=%E7%BD%91%E8%AD%A6%EF%BC%9A%E5%BD%93%E5%BF%83%E4%BD%A0%E7%9A%84%E9%9A%90%E7%A7%81%E8%A2%AB%E2%80%9C%E5%85%B1%E4%BA%AB%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:57:20 8     迪丽热巴因一句台词一夜涨粉200万
#  URL: https://www.baidu.com/s?wd=%E8%BF%AA%E4%B8%BD%E7%83%AD%E5%B7%B4%E5%9B%A0%E4%B8%80%E5%8F%A5%E5%8F%B0%E8%AF%8D%E4%B8%80%E5%A4%9C%E6%B6%A8%E7%B2%89200%E4%B8%87&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:57:20 9     “赌王”孙女街头摆摊当小贩
#  URL: https://www.baidu.com/s?wd=%E2%80%9C%E8%B5%8C%E7%8E%8B%E2%80%9D%E5%AD%99%E5%A5%B3%E8%A1%97%E5%A4%B4%E6%91%86%E6%91%8A%E5%BD%93%E5%B0%8F%E8%B4%A9&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:57:20 10    种粮大户的“丰收密码”
#  URL: https://www.baidu.com/s?wd=%E7%A7%8D%E7%B2%AE%E5%A4%A7%E6%88%B7%E7%9A%84%E2%80%9C%E4%B8%B0%E6%94%B6%E5%AF%86%E7%A0%81%E2%80%9D&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:56:52 1     总书记的“家园”之喻
#  URL: https://www.baidu.com/s?wd=%E6%80%BB%E4%B9%A6%E8%AE%B0%E7%9A%84%E2%80%9C%E5%AE%B6%E5%9B%AD%E2%80%9D%E4%B9%8B%E5%96%BB&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:56:52 1     总书记的“家园”之喻
#  URL: https://www.baidu.com/s?wd=%E6%80%BB%E4%B9%A6%E8%AE%B0%E7%9A%84%E2%80%9C%E5%AE%B6%E5%9B%AD%E2%80%9D%E4%B9%8B%E5%96%BB&sa=fyb_news&rsv_dl=fyb_news
# 2025-06-11 22:56:52